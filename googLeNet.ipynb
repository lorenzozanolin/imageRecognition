# %%
#    MODEL FROM ZANOLIN LORENZO
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory

cudnn.benchmark = True
plt.ion()   # interactive mode

# %% [markdown]
# ## Load Data

# %%
# Data augmentation and normalization for training
# Data augmentation and normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(p=1),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(p=1),
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}
# !unzip -u "./dataset.zip" -d "./dataset"
data_dir = './dataset/dataset'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Archive:  ./dataset.zip
#    creating: ./dataset/dataset/
#   inflating: ./dataset/__MACOSX/._dataset
#   inflating: ./dataset/dataset/.DS_Store
#   inflating: ./dataset/__MACOSX/dataset/._.DS_Store
#    creating: ./dataset/dataset/train/
#   inflating: ./dataset/__MACOSX/dataset/._train
#    creating: ./dataset/dataset/val/
#   inflating: ./dataset/__MACOSX/dataset/._val
#    creating: ./dataset/dataset/train/car/
#   inflating: ./dataset/__MACOSX/dataset/train/._car
#    creating: ./dataset/dataset/train/fruit/
#   inflating: ./dataset/__MACOSX/dataset/train/._fruit
#    creating: ./dataset/dataset/train/moto/
#   inflating: ./dataset/__MACOSX/dataset/train/._moto
#    creating: ./dataset/dataset/train/furniture/
#   inflating: ./dataset/__MACOSX/dataset/train/._furniture
#    creating: ./dataset/dataset/val/car/
#   inflating: ./dataset/__MACOSX/dataset/val/._car
#    creating: ./dataset/dataset/val/fruit/
#   inflating: ./dataset/__MACOSX/dataset/val/._fruit
#    creating: ./dataset/dataset/val/moto/
#   inflating: ./dataset/__MACOSX/dataset/val/._moto
#    creating: ./dataset/dataset/val/furniture/
#   inflating: ./dataset/__MACOSX/dataset/val/._furniture
#   inflating: ./dataset/dataset/train/car/images.jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/car/._images.jpeg
#   inflating: ./dataset/dataset/train/car/images (10).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/car/._images (10).jpeg
#   inflating: ./dataset/dataset/train/car/images (6).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/car/._images (6).jpeg
#   inflating: ./dataset/dataset/train/car/images (11).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/car/._images (11).jpeg
#   inflating: ./dataset/dataset/train/car/images (7).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/car/._images (7).jpeg
#   inflating: ./dataset/dataset/train/car/images (5).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/car/._images (5).jpeg
#   inflating: ./dataset/dataset/train/car/images (9).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/car/._images (9).jpeg
#   inflating: ./dataset/dataset/train/car/images (8).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/car/._images (8).jpeg
#   inflating: ./dataset/dataset/train/fruit/images (2).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/fruit/._images (2).jpeg
#   inflating: ./dataset/dataset/train/fruit/images (4).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/fruit/._images (4).jpeg
#   inflating: ./dataset/dataset/train/fruit/images.jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/fruit/._images.jpeg
#   inflating: ./dataset/dataset/train/fruit/images (6).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/fruit/._images (6).jpeg
#   inflating: ./dataset/dataset/train/fruit/images (3).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/fruit/._images (3).jpeg
#   inflating: ./dataset/dataset/train/fruit/images (7).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/fruit/._images (7).jpeg
#   inflating: ./dataset/dataset/train/fruit/images (5).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/fruit/._images (5).jpeg
#   inflating: ./dataset/dataset/train/fruit/pasta-salad-horizontal-jpg-1522265695.jpg
#   inflating: ./dataset/__MACOSX/dataset/train/fruit/._pasta-salad-horizontal-jpg-1522265695.jpg
#   inflating: ./dataset/dataset/train/moto/morini-xcape_orig.jpg
#   inflating: ./dataset/__MACOSX/dataset/train/moto/._morini-xcape_orig.jpg
#   inflating: ./dataset/dataset/train/moto/images (4).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/moto/._images (4).jpeg
#   inflating: ./dataset/dataset/train/moto/images.jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/moto/._images.jpeg
#   inflating: ./dataset/dataset/train/moto/images (6).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/moto/._images (6).jpeg
#   inflating: ./dataset/dataset/train/moto/images (7).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/moto/._images (7).jpeg
#   inflating: ./dataset/dataset/train/moto/images (5).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/moto/._images (5).jpeg
#   inflating: ./dataset/dataset/train/moto/images (8).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/moto/._images (8).jpeg
#   inflating: ./dataset/dataset/train/moto/RR-Racing-my24-125-2T-right.jpg
#   inflating: ./dataset/__MACOSX/dataset/train/moto/._RR-Racing-my24-125-2T-right.jpg
#   inflating: ./dataset/dataset/train/furniture/images.jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/furniture/._images.jpeg
#   inflating: ./dataset/dataset/train/furniture/images (10).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/furniture/._images (10).jpeg
#   inflating: ./dataset/dataset/train/furniture/images (6).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/furniture/._images (6).jpeg
#   inflating: ./dataset/dataset/train/furniture/images (11).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/furniture/._images (11).jpeg
#   inflating: ./dataset/dataset/train/furniture/images (7).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/furniture/._images (7).jpeg
#   inflating: ./dataset/dataset/train/furniture/images (5).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/furniture/._images (5).jpeg
#   inflating: ./dataset/dataset/train/furniture/images (9).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/furniture/._images (9).jpeg
#   inflating: ./dataset/dataset/train/furniture/images (8).jpeg
#   inflating: ./dataset/__MACOSX/dataset/train/furniture/._images (8).jpeg
#   inflating: ./dataset/dataset/val/car/images (2).jpeg
#   inflating: ./dataset/dataset/val/car/images (4).jpeg
#   inflating: ./dataset/__MACOSX/dataset/val/car/._images (4).jpeg
#   inflating: ./dataset/dataset/val/car/images (1).jpeg
#   inflating: ./dataset/dataset/val/car/images (3).jpeg
#   inflating: ./dataset/__MACOSX/dataset/val/car/._images (3).jpeg
#   inflating: ./dataset/dataset/val/fruit/fresh-sliced-mini-kiwis-royalty-free-image-1690215764.jpg
#   inflating: ./dataset/dataset/val/fruit/fall-fruits-6482308fc371c.jpg
#   inflating: ./dataset/dataset/val/fruit/images (1).jpeg
#   inflating: ./dataset/__MACOSX/dataset/val/fruit/._images (1).jpeg
#   inflating: ./dataset/dataset/val/fruit/high-and-low-carb-fruits-main-1515515761.jpg
#   inflating: ./dataset/__MACOSX/dataset/val/fruit/._high-and-low-carb-fruits-main-1515515761.jpg
#   inflating: ./dataset/dataset/val/moto/images (2).jpeg
#   inflating: ./dataset/__MACOSX/dataset/val/moto/._images (2).jpeg
#   inflating: ./dataset/dataset/val/moto/165656730-0db94b11-3522-4a4a-99ae-53f946421c7b.jpg
#   inflating: ./dataset/dataset/val/moto/images (1).jpeg
#   inflating: ./dataset/dataset/val/moto/images (3).jpeg
#   inflating: ./dataset/__MACOSX/dataset/val/moto/._images (3).jpeg
#   inflating: ./dataset/dataset/val/furniture/images (2).jpeg
#   inflating: ./dataset/dataset/val/furniture/images (4).jpeg
#   inflating: ./dataset/__MACOSX/dataset/val/furniture/._images (4).jpeg
#   inflating: ./dataset/dataset/val/furniture/images (1).jpeg
#   inflating: ./dataset/dataset/val/furniture/images (3).jpeg
#   inflating: ./dataset/__MACOSX/dataset/val/furniture/._images (3).jpeg
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# ## Dataset visualization

# %%
def imshow(inp, title=None):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# # Some useful functions

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                else:
                    model.eval()   # Set model to evaluate mode

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels in dataloaders[phase]:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)
                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'val' and epoch_acc > best_acc:
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)

            print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path))
    return model

def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# # Model import and finetuning

# %%
model_ft = models.googlenet(weights='IMAGENET1K_V1')
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/googlenet-1378be20.pth" to /root/.cache/torch/hub/checkpoints/googlenet-1378be20.pth
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 114MB/s]

# %% [markdown]
# ## Training and Evaluation

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 1.4600 Acc: 0.1875
# val Loss: 1.3479 Acc: 0.3125
#
# Epoch 1/24
# ----------
# train Loss: 1.2008 Acc: 0.5625
# val Loss: 1.1704 Acc: 0.8125
#
# Epoch 2/24
# ----------
# train Loss: 1.0656 Acc: 0.7500
# val Loss: 0.9266 Acc: 0.8750
#
# Epoch 3/24
# ----------
# train Loss: 0.9241 Acc: 0.8438
# val Loss: 0.7668 Acc: 0.9375
#
# Epoch 4/24
# ----------
# train Loss: 0.7390 Acc: 0.8750
# val Loss: 0.6383 Acc: 1.0000
#
# Epoch 5/24
# ----------
# train Loss: 0.5660 Acc: 0.9062
# val Loss: 0.5237 Acc: 1.0000
#
# Epoch 6/24
# ----------
# train Loss: 0.6675 Acc: 0.7812
# val Loss: 0.4908 Acc: 0.8750
#
# Epoch 7/24
# ----------
# train Loss: 0.3753 Acc: 1.0000
# val Loss: 0.3436 Acc: 1.0000
#
# Epoch 8/24
# ----------
# train Loss: 0.5064 Acc: 0.9062
# val Loss: 0.4747 Acc: 0.9375
#
# Epoch 9/24
# ----------
# train Loss: 0.4485 Acc: 0.9375
# val Loss: 0.3800 Acc: 1.0000
#
# Epoch 10/24
# ----------
# train Loss: 0.4800 Acc: 0.9375
# val Loss: 0.3055 Acc: 1.0000
#
# Epoch 11/24
# ----------
# train Loss: 0.6090 Acc: 0.8438
# val Loss: 0.3252 Acc: 1.0000
#
# Epoch 12/24
# ----------
# train Loss: 0.5130 Acc: 0.8438
# val Loss: 0.4333 Acc: 0.9375
#
# Epoch 13/24
# ----------
# train Loss: 0.4302 Acc: 0.9375
# val Loss: 0.3543 Acc: 1.0000
#
# Epoch 14/24
# ----------
# train Loss: 0.4259 Acc: 0.8750
# val Loss: 0.3672 Acc: 1.0000
#
# Epoch 15/24
# ----------
# train Loss: 0.3822 Acc: 0.9688
# val Loss: 0.4111 Acc: 1.0000
#
# Epoch 16/24
# ----------
# train Loss: 0.4617 Acc: 0.9062
# val Loss: 0.3988 Acc: 1.0000
#
# Epoch 17/24
# ----------
# train Loss: 0.3860 Acc: 0.9375
# val Loss: 0.2856 Acc: 1.0000
#
# Epoch 18/24
# ----------
# train Loss: 0.7835 Acc: 0.7500
# val Loss: 0.3818 Acc: 1.0000
#
# Epoch 19/24
# ----------
# train Loss: 0.5080 Acc: 0.9375
# val Loss: 0.4104 Acc: 1.0000
#
# Epoch 20/24
# ----------
# train Loss: 0.4365 Acc: 0.9688
# val Loss: 0.3215 Acc: 1.0000
#
# Epoch 21/24
# ----------
# train Loss: 0.4591 Acc: 0.9375
# val Loss: 0.3595 Acc: 1.0000
#
# Epoch 22/24
# ----------
# train Loss: 0.5072 Acc: 0.9062
# val Loss: 0.3804 Acc: 1.0000
#
# Epoch 23/24
# ----------
# train Loss: 0.7399 Acc: 0.7500
# val Loss: 0.4121 Acc: 1.0000
#
# Epoch 24/24
# ----------
# train Loss: 0.4801 Acc: 0.8750
# val Loss: 0.3533 Acc: 1.0000
#
# Training complete in 5m 28s
# Best val Acc: 1.000000

# %% [markdown]
# ## Visualizing the results

# %%
visualize_model(model_ft)
